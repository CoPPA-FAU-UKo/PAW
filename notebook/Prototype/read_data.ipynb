# %% [markdown]
# # Read and preprocess data

# %%
import numpy as np
import pandas as pd
import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import pickle as pickle
from src.Log import Reformat

from sklearn import preprocessing

# %% [markdown]
# ## Read data

# %%
data = pd.read_json("../../data/2024-06_04_camunda_test_export.json")
data["startDate"] = data["startDate"].apply(pd.to_datetime)
data["endDate"] = data["endDate"].apply(pd.to_datetime)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = pd.read_json("../../data/2024-06_04_camunda_test_export.json")
#       2 data["startDate"] = data["startDate"].apply(pd.to_datetime)
#       3 data["endDate"] = data["endDate"].apply(pd.to_datetime)
#
# File ~/anaconda3/envs/TL4PM/lib/python3.8/site-packages/pandas/io/json/_json.py:760, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     757 if convert_axes is None and orient != "table":
#     758     convert_axes = True
# --> 760 json_reader = JsonReader(
#     761     path_or_buf,
#     762     orient=orient,
#     763     typ=typ,
#     764     dtype=dtype,
#     765     convert_axes=convert_axes,
#     766     convert_dates=convert_dates,
#     767     keep_default_dates=keep_default_dates,
#     768     precise_float=precise_float,
#     769     date_unit=date_unit,
#     770     encoding=encoding,
#     771     lines=lines,
#     772     chunksize=chunksize,
#     773     compression=compression,
#     774     nrows=nrows,
#     775     storage_options=storage_options,
#     776     encoding_errors=encoding_errors,
#     777     dtype_backend=dtype_backend,
#     778     engine=engine,
#     779 )
#     781 if chunksize:
#     782     return json_reader
#
# File ~/anaconda3/envs/TL4PM/lib/python3.8/site-packages/pandas/io/json/_json.py:861, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
#     859     self.data = filepath_or_buffer
#     860 elif self.engine == "ujson":
# --> 861     data = self._get_data_from_filepath(filepath_or_buffer)
#     862     self.data = self._preprocess_data(data)
#
# File ~/anaconda3/envs/TL4PM/lib/python3.8/site-packages/pandas/io/json/_json.py:917, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     909     filepath_or_buffer = self.handles.handle
#     910 elif (
#     911     isinstance(filepath_or_buffer, str)
#     912     and filepath_or_buffer.lower().endswith(
#    (...)
#     915     and not file_exists(filepath_or_buffer)
#     916 ):
# --> 917     raise FileNotFoundError(f"File {filepath_or_buffer} does not exist")
#     919 return filepath_or_buffer
#
# FileNotFoundError: File ../../data/2024-06_04_camunda_test_export.json does not exist

# %% [markdown]
# ## Filter unfinished

# %%
data_fin = data[data["nodeState"] == "COMPLETED"].drop(columns=["nodeState"])
data_fin = data_fin[data_fin["processState"] == "COMPLETED"].drop(columns=["processState"])
data_fin = data_fin.rename(columns={"processInstanceKey": "Case ID", "flowNodeId": "Activity"})

# %%
data_fin
# Out:
#                    key           Case ID          Activity   nodeType  \
# 0     2251799814059556  2251799814059549  Activity_0kwkee3  USER_TASK
# 1     2251799814059616  2251799814059549  Activity_10j4ubx  USER_TASK
# 2     2251799814059716  2251799814059549  Activity_1qen0ov  USER_TASK
# 3     2251799814059565  2251799814059558  Activity_0kwkee3  USER_TASK
# 4     2251799814059583  2251799814059558  Activity_10j4ubx  USER_TASK
# ...                ...               ...               ...        ...
# 4447  2251799814113254  2251799814112976  Activity_0btrsy1  USER_TASK
# 4448  2251799814113371  2251799814112976  Activity_0systjc  USER_TASK
# 4449  2251799814113412  2251799814112976  Activity_0systjc  USER_TASK
# 4450  2251799814113530  2251799814112976  Activity_0rdg80t  USER_TASK
# 4451  2251799814113642  2251799814112976  Activity_1qen0ov  USER_TASK
#
#       nodeIncident    nextFlowNodeId                        startDate  \
# 0            False  Activity_10j4ubx 2024-06-03 08:35:03.943000+00:00
# 1            False  Activity_1qen0ov 2024-06-03 08:35:15.705000+00:00
# 2            False     Event_1m6kx19 2024-06-03 08:35:29.939000+00:00
# 3            False  Activity_10j4ubx 2024-06-03 08:35:04.466000+00:00
# 4            False  Activity_1qen0ov 2024-06-03 08:35:08.788000+00:00
# ...            ...               ...                              ...
# 4447         False  Activity_0systjc 2024-06-03 11:09:49.276000+00:00
# 4448         False  Activity_0systjc 2024-06-03 11:10:13.344000+00:00
# 4449         False  Activity_0rdg80t 2024-06-03 11:10:22.384000+00:00
# 4450         False  Activity_1qen0ov 2024-06-03 11:10:44.463000+00:00
# 4451         False     Event_1m6kx19 2024-06-03 11:10:58.621000+00:00
#
#                               endDate  processVersion bpmnProcessId  \
# 0    2024-06-03 08:35:15.705000+00:00               6    Sim_Test_1
# 1    2024-06-03 08:35:29.939000+00:00               6    Sim_Test_1
# 2    2024-06-03 08:35:51.117000+00:00               6    Sim_Test_1
# 3    2024-06-03 08:35:08.788000+00:00               6    Sim_Test_1
# 4    2024-06-03 08:35:13.785000+00:00               6    Sim_Test_1
# ...                               ...             ...           ...
# 4447 2024-06-03 11:10:13.344000+00:00               6    Sim_Test_1
# 4448 2024-06-03 11:10:22.384000+00:00               6    Sim_Test_1
# 4449 2024-06-03 11:10:44.463000+00:00               6    Sim_Test_1
# 4450 2024-06-03 11:10:58.621000+00:00               6    Sim_Test_1
# 4451 2024-06-03 11:11:15.102000+00:00               6    Sim_Test_1
#
#       processDefinitionKey variablesString variablesDouble  \
# 0         2251799814059278              {}              {}
# 1         2251799814059278              {}              {}
# 2         2251799814059278              {}              {}
# 3         2251799814059278              {}              {}
# 4         2251799814059278              {}              {}
# ...                    ...             ...             ...
# 4447      2251799814059278              {}              {}
# 4448      2251799814059278              {}              {}
# 4449      2251799814059278              {}              {}
# 4450      2251799814059278              {}              {}
# 4451      2251799814059278              {}              {}
#
#                                           variablesBool  \
# 0     {'guestArrival': False, 'fittingRoom': True, '...
# 1     {'guestArrival': False, 'fittingRoom': True, '...
# 2     {'guestArrival': False, 'fittingRoom': True, '...
# 3     {'guestArrival': False, 'fittingRoom': True, '...
# 4     {'guestArrival': False, 'fittingRoom': True, '...
# ...                                                 ...
# 4447  {'guestArrival': True, 'fittingRoom': True, 'c...
# 4448  {'guestArrival': True, 'fittingRoom': True, 'c...
# 4449  {'guestArrival': True, 'fittingRoom': True, 'c...
# 4450  {'guestArrival': True, 'fittingRoom': True, 'c...
# 4451  {'guestArrival': True, 'fittingRoom': True, 'c...
#
#                                           executionFlow  nodeDuration  \
# 0                                   {'StartEvent_1': 1}         11762
# 1     {'Gateway_1iifgjl': 1, 'Activity_0kwkee3': 1, ...         14234
# 2     {'Gateway_1iifgjl': 1, 'Gateway_097vsc3': 1, '...         21178
# 3                                   {'StartEvent_1': 1}          4322
# 4     {'Gateway_1iifgjl': 1, 'Activity_0kwkee3': 1, ...          4997
# ...                                                 ...           ...
# 4447  {'Gateway_1iifgjl': 1, 'Gateway_097vsc3': 1, '...         24068
# 4448  {'Gateway_1iifgjl': 1, 'Gateway_097vsc3': 1, '...          9040
# 4449  {'Gateway_1iifgjl': 1, 'Gateway_097vsc3': 1, '...         22079
# 4450  {'Gateway_1iifgjl': 1, 'Gateway_097vsc3': 1, '...         14158
# 4451  {'Gateway_1iifgjl': 1, 'Gateway_097vsc3': 1, '...         16481
#
#       processDuration
# 0               47174
# 1               47174
# 2               47174
# 3               13780
# 4               13780
# ...               ...
# 4447           139091
# 4448           139091
# 4449           139091
# 4450           139091
# 4451           139091
#
# [4452 rows x 17 columns]

# %% [markdown]
# ## Encode Cat feature

# %%
def label_encoding(column):
    le = preprocessing.LabelEncoder()
    le.fit(column)
    le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
    le_class_mapping = dict(zip(le.transform(le.classes_), le.classes_))
    return le.transform(column), le_name_mapping, le_class_mapping

le_map = {}
for column in data_fin.columns:
    if column != "processInstanceKey" and type(data_fin[column][0]) == str:
        data_fin[column], name_mapping, class_mapping = label_encoding(data_fin[column])
        le_map[column] = {"name_mapping": name_mapping, "class_mapping": class_mapping}

# %%
le_map_pd = pd.DataFrame(data=le_map)
le_map_pd.to_pickle("../../data/t1_label_encode.pkl")

# %%
data_core = data_fin[["Case ID", "Activity", "endDate"]]

# %%
data_core
# Out:
#                Case ID  Activity                          endDate
# 0     2251799814059549         1 2024-06-03 08:35:15.705000+00:00
# 1     2251799814059549         5 2024-06-03 08:35:29.939000+00:00
# 2     2251799814059549         6 2024-06-03 08:35:51.117000+00:00
# 3     2251799814059558         1 2024-06-03 08:35:08.788000+00:00
# 4     2251799814059558         5 2024-06-03 08:35:13.785000+00:00
# ...                ...       ...                              ...
# 4447  2251799814112976         0 2024-06-03 11:10:13.344000+00:00
# 4448  2251799814112976         4 2024-06-03 11:10:22.384000+00:00
# 4449  2251799814112976         4 2024-06-03 11:10:44.463000+00:00
# 4450  2251799814112976         3 2024-06-03 11:10:58.621000+00:00
# 4451  2251799814112976         6 2024-06-03 11:11:15.102000+00:00
#
# [4452 rows x 3 columns]

# %%
data_trace = Reformat.roll_sequence(data_core, time_column="endDate", case_column="Case ID")

# %%
data_trace = data_trace.reset_index()

# %%
def cal_remtime(time_stamp_arr):
    return (time_stamp_arr[-1] - time_stamp_arr).astype('timedelta64[s]').astype(int)

def cal_lapse(time_stamp_arr):
    return -(time_stamp_arr[0] - time_stamp_arr).astype('timedelta64[s]').astype(int)

data_trace["RemTime"] = data_trace["endDate"].apply(cal_remtime)
data_trace["LapseTime"] = data_trace["endDate"].apply(cal_lapse)

# %%
data_trace["RemTime"] = data_trace["RemTime"]/295
data_trace["LapseTime"] = data_trace["LapseTime"]/295

# %%
data_trace
# Out:
#               Case ID               Activity  \
# 0    2251799814059558              [1, 5, 6]
# 1    2251799814059549              [1, 5, 6]
# 2    2251799814059567              [1, 5, 6]
# 3    2251799814059618     [1, 5, 0, 4, 3, 6]
# 4    2251799814059631                 [1, 2]
# ..                ...                    ...
# 995  2251799814112619  [1, 2, 5, 0, 4, 3, 6]
# 996  2251799814112667              [1, 5, 6]
# 997  2251799814112774  [1, 5, 0, 4, 4, 3, 6]
# 998  2251799814112976  [1, 5, 0, 4, 4, 3, 6]
# 999  2251799814112967                 [1, 2]
#
#                                                endDate  \
# 0    [2024-06-03 08:35:08.788000+00:00, 2024-06-03 ...
# 1    [2024-06-03 08:35:15.705000+00:00, 2024-06-03 ...
# 2    [2024-06-03 08:35:20.021000+00:00, 2024-06-03 ...
# 3    [2024-06-03 08:35:28.738000+00:00, 2024-06-03 ...
# 4    [2024-06-03 08:35:31.857000+00:00, 2024-06-03 ...
# ..                                                 ...
# 995  [2024-06-03 11:08:24.761000+00:00, 2024-06-03 ...
# 996  [2024-06-03 11:08:32.824000+00:00, 2024-06-03 ...
# 997  [2024-06-03 11:08:34.839000+00:00, 2024-06-03 ...
# 998  [2024-06-03 11:09:24.179000+00:00, 2024-06-03 ...
# 999  [2024-06-03 11:09:27.203000+00:00, 2024-06-03 ...
#
#                           Start Time  \
# 0   2024-06-03 08:35:08.788000+00:00
# 1   2024-06-03 08:35:15.705000+00:00
# 2   2024-06-03 08:35:20.021000+00:00
# 3   2024-06-03 08:35:28.738000+00:00
# 4   2024-06-03 08:35:31.857000+00:00
# ..                               ...
# 995 2024-06-03 11:08:24.761000+00:00
# 996 2024-06-03 11:08:32.824000+00:00
# 997 2024-06-03 11:08:34.839000+00:00
# 998 2024-06-03 11:09:24.179000+00:00
# 999 2024-06-03 11:09:27.203000+00:00
#
#                                                RemTime  \
# 0    [0.030508474576271188, 0.013559322033898305, 0.0]
# 1       [0.11864406779661017, 0.0711864406779661, 0.0]
# 2      [0.0847457627118644, 0.061016949152542375, 0.0]
# 3    [0.17627118644067796, 0.1152542372881356, 0.08...
# 4                          [0.030508474576271188, 0.0]
# ..                                                 ...
# 995  [0.4135593220338983, 0.34576271186440677, 0.29...
# 996     [0.1016949152542373, 0.09152542372881356, 0.0]
# 997  [0.46779661016949153, 0.3898305084745763, 0.28...
# 998  [0.3728813559322034, 0.288135593220339, 0.2067...
# 999                         [0.05084745762711865, 0.0]
#
#                                              LapseTime
# 0      [0.0, 0.01694915254237288, 0.03389830508474576]
# 1      [0.0, 0.05084745762711865, 0.12203389830508475]
# 2     [0.0, 0.023728813559322035, 0.08813559322033898]
# 3    [0.0, 0.06440677966101695, 0.09152542372881356...
# 4                           [0.0, 0.03389830508474576]
# ..                                                 ...
# 995  [0.0, 0.0711864406779661, 0.12203389830508475,...
# 996   [0.0, 0.013559322033898305, 0.10508474576271186]
# 997  [0.0, 0.07796610169491526, 0.1864406779661017,...
# 998  [0.0, 0.08813559322033898, 0.1694915254237288,...
# 999                         [0.0, 0.05423728813559322]
#
# [1000 rows x 6 columns]

# %%
data_trace[:640].to_pickle("../../data/t1_train.pkl")
data_trace[640:800].to_pickle("../../data/t1_val.pkl")
data_trace[800:].to_pickle("../../data/t1_test.pkl")

# %%
data_trace.to_pickle("../../data/test1.pkl")

# %%
data_read = pd.read_pickle("../data/test1.pkl")

# %%
data_read.columns.values
# Out:
# array(['Case ID', 'Activity', 'endDate', 'Start Time', 'RemTime',
#        'LapseTime'], dtype=object)

# %%
len(le_map["Activity"]['name_mapping'])
# Out:
# 6
