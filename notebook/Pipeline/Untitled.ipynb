# %%
import pandas as pd

# %%
pd.read_json("/home/ap43owus/Projects/CoPPA_Trainer/data/SimulatedLogs/bpmn1-log.json")
# Out:
#                    key  processInstanceKey     flowNodeId          nodeType  \
# 0     2251799814399243    2251799814399238     Task_eb116         USER_TASK
# 1     2251799814401541    2251799814399238     Task_e443d         USER_TASK
# 2     2251799814401616    2251799814399238     Task_f7c1b         USER_TASK
# 3     2251799814401871    2251799814399238  Gateway_1d41f  PARALLEL_GATEWAY
# 4     2251799814401873    2251799814399238     Task_1846d         USER_TASK
# ...                ...                 ...            ...               ...
# 5721  2251799814423856    2251799814423851     Task_eb116         USER_TASK
# 5722  2251799814423903    2251799814423851     Task_e443d         USER_TASK
# 5723  2251799814424007    2251799814423851     Task_f7c1b         USER_TASK
# 5724  2251799814424078    2251799814423851  Gateway_1d41f  PARALLEL_GATEWAY
# 5725  2251799814423947    2251799814423942     Task_eb116         USER_TASK
#
# ...
